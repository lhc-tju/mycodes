# %%
import re
import requests 
from bs4 import BeautifulSoup

from selenium import webdriver # 从selenium导入webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep

opt = webdriver.ChromeOptions() #无界面模式
opt.set_headless()
opt.add_argument('user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36"')
driver = webdriver.Chrome(options=opt)
driver.get('https://baike.baidu.com/item/%E7%99%BE%E5%BA%A6%E7%99%BE%E7%A7%91')
input_text = driver.find_element_by_id('query')
input_text.clear()
input_text.send_keys('雷根强')
input_text.send_keys(Keys.ENTER)
data = driver.page_source
soup = BeautifulSoup(data,'lxml')
title = soup.select('.main-content')[0].find('h1')
result = soup.select('.main-content')[0].text
if result.find('财政') == -1 and result.find('税务') == -1 and result.find('财税') == -1:
    continue

names = ['樊丽明',
'郭庆旺',
'雷根强',
'杨灿明',
'李俊生',
'王乔',
'马骁',
'刘小兵',
'计金标',
'王晓洁',
'白贵',
'孙开',
'杨春梅',
'王莹',
'李林木',
'钟晓敏',
'倪志良',
'廉桂萍',
'杨志安',
'年志远',
'石磊',
'陈东平',
'裴育',
'李光龙',
'郝书辰',
'随新玉',
'林江',
'朱红琼',
'李香菊',
'张世强',
'卢洪友',
'于海峰',
'罗美娟',
'崔光莲',
'石绍宾',
'刘怡',
'郑榕',
'姚东旭',
'何德旭',
'宋凤轩',
'崔惠玉',
'王曙光',
'陈诗一',
'杨光焰',
'方红生',
'田淑英',
'经庭如',
'朱德云',
'蔡玉平',
'孙世强',
'董云展',
'刘穷志',
'沈肇章',
'伏润民',
'宋丽颖',
'赵国春']
# Out:
# 收藏
# 查看我的收藏
#
#
#
# 18
# 有用+1
# 已投票
#
#
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 雷根强
# 编辑
# 锁定
#
#
#
# 雷根强  1963年2月生，福建南安人，经济学博士、教授，厦门大学经济学院博士生导师。注册税务师。1983年8月参加工作，1992年1月加入中国共产党。中国财政学会理事、中国税务学会理事、中国税收教学研究会副会长。
# [1]
#
#
#
#
#
# 中文名
#
# 雷根强
#
# 国    籍
#
# 中国
#
# 出生地
#
# 福建南安
#
# 出生日期
#
# 1963年2月
#
# 职    业
#
# 教师
#
# 毕业院校
#
# 厦门大学
#
#
# 学位/学历
#
# 博士
#
# 专业方向
#
# 财税理论与政策
#
# 职    务
#
# 博士生导师、教授
#
# 主要成就
#
# 《涉外税收优惠与外商直接投资》，第三次全国税收理论研究成果一等奖，（排名第一，1999年）。
#
# 学术代表作
#
# 税收学， 编著 ， 科学出版社， 2003
#
#
#
#
# 目录
#
#
#
# 1
# 基本情况
#
#
# ▪
# 教育经历
#
#
# ▪
# 工作经历
#
#
# ▪
# 主授课程
#
#
# ▪
# 荣誉兼职
#
#
# 2
# 主要研究领域与项目
#
#
# ▪
# 研究领域
#
#
# ▪
# 科研项目
#
#
# 3
# 主要学术成果与获奖
#
#
# ▪
# 学术成果
#
#
# ▪
# 荣誉获奖
#
#
#
#
#
#
#
#
#
#
# 雷根强基本情况
# 编辑
#
#
#
#
#
#
#
# 雷根强教育经历
#
# 1979年9月—1983年7月厦门大学财政金融专业，学士。
# 1986年9月—1989年7月 厦门大学财政学专业，硕士。
# 1994年9月—1997年8月 厦门大学财政学专业，博士。
# 2007年3月1日—2007年3月28日 中共中央党校，结业。
#
#
#
#
#
# 雷根强工作经历
#
# 1983年8月起在厦门大学财政金融系工作，历任助教、讲师（1988年）、副教授（1993年）、教授（2001年）。
# 2002年获博士生导师资格
# ...
