# %% [markdown]
# ## 首都经济贸易大学发展情况（2016-2019）

# %% [markdown]
# #### 首经贸2016-2019发展情况概览

# %%
# Out:
#                 类别   数目
#            国家社科项目数   89
#          国家自然基金项目数   45
#                 教材  469
#              教育部项目   12
#        师资数据-国家优秀青年    1
#   外文期刊-SCI/SSCI论文数  346
#       中文期刊-南大C刊论文数  931

# %% [markdown]
# #### 中文期刊论文-南大C刊

# %% [markdown]
# #### 外文期刊论文-SCI/SSCI

# %% [markdown]
# #### 国家社科项目

# %% [markdown]
# #### 国家自然基金项目

# %% [markdown]
# #### 教育部项目

# %% [markdown]
# 注：数据来源于教育部、国家社科基金项目数据库、LetPub国家自然基金项目数据库、国家图书馆、国内外主流期刊论文平台等

# %% [markdown]
# ###### 以上报表的数据已经过初步筛选，仅供参考，原始数据可以参照附件里的数据包
# ###### 北京百智享科技有限公司 2019-6-11
