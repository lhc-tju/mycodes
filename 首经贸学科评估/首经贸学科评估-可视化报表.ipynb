# %% [markdown]
# ## 首都经济贸易大学学科评估（2016-2019）

# %% [markdown]
# ### 首经贸 2016 - 2019 年 3 学科发展情况概览

# %%
注:大口径为南京大学C刊目录,小口径为需求表中所列期刊
# Out:
#        SCI/SSCI论文数  国家社科基金项目数  国家自然基金项目数  大口径-论文数  小口径-论文数    教材数  教育部项目数
# 应用经济学        109.0       10.0       15.0    355.0     49.0  153.0     5.0
# 工商管理         103.0       17.0       18.0    128.0     99.0  122.0     4.0
# 统计学           23.0        3.0        8.0     52.0     23.0    9.0     0.0

# %%
首经贸-中文期刊发文数统计-大口径

# %%
首经贸-中文期刊发文数统计-小口径

# %%
首经贸-外文期刊发文数统计

# %% [markdown]
# ### 首经贸-学科关键词

# %%
首经贸-应用经济学-关键词云(南大C刊)

# %%
首经贸-工商管理-关键词云(南大C刊)

# %%
首经贸-统计学-关键词云(南大C刊)

# %% [markdown]
# ### 高校各学科发展情况比较（2016-2019）

# %% [markdown]
# #### 应用经济学

# %%
应用经济学-中文期刊发文数对比

# %%
应用经济学-外文期刊-SCI/SSCI发文数对比

# %%
应用经济学-国家社科基金项目/国家自然基金项目对比

# %%
应用经济学-教育部项目对比

# %% [markdown]
# #### 工商管理

# %%
工商管理-中文期刊发文数对比

# %%
工商管理-外文期刊-SCI/SSCI发文数对比

# %%
工商管理-国家社科基金项目/国家自然基金项目对比

# %%
工商管理-教育部项目

# %% [markdown]
# #### 统计学

# %%
统计学-中文期刊发文数对比

# %%
统计学-外文期刊-SCI/SSCI发文数对比

# %%
统计学-国家社科基金项目/国家自然基金项目对比

# %%
统计学-教育部项目

# %% [markdown]
# 注：数据来源于教育部、国家社科基金项目数据库、LetPub国家自然基金项目数据库、国家图书馆、国内外主流期刊论文平台等

# %% [markdown]
# ###### 以上报表的数据已经过初步筛选，仅供参考，原始数据可以参照附件里的数据包
# ###### 北京百智享科技有限公司 2019-6-11
